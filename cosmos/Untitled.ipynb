# %%
from astropy.io import fits

# %%
from astropy.table import Table

# %%
hdulist = fits.open('COSMOS2015_Laigle+_v1.1.fits')

# %%
hdulist[1].data[0][2]
# Out:
# 1

# %%
TT=Table(hdulist[1].data)

# %%
N=['ALPHA_J2000','DELTA_J2000','NUMBER','r_MAG_AUTO','ZPDF']

# %%
Tabl2=TT[N]

# %%
#Tabl2.write('data.dat',format='ascii')
Tabl2.write('data_R_whole.dat',format='ascii.ipac')
# Out:
# WARNING: AstropyDeprecationWarning: data_R_whole.dat already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]

# %%
hdulist[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                 2364 / width of table in bytes
# NAXIS2  =               133358 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  556 / number of columns
# EXTNAME = 'Joined  '           / table name
# TTYPE1  = 'ALPHA_J2000'        / label for column 1
# TFORM1  = 'D       '           / format for column 1
# TUNIT1  = 'deg     '           / units for column 1
# TTYPE2  = 'DELTA_J2000'        / label for column 2
# TFORM2  = 'D       '           / format for column 2
# TUNIT2  = 'deg     '           / units for column 2
# TTYPE3  = 'NUMBER  '           / label for column 3
# TFORM3  = 'K       '           / format for column 3
# TTYPE4  = 'X_IMAGE '           / label for column 4
# ...

# %%
import numpy as np

# %%
hdulist = fits.open('matched_COSMOS_Laigle.fits')

# %%
TT2=Table(hdulist[1].data)

# %%
hdulist[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                 2364 / width of table in bytes
# NAXIS2  =               133358 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  556 / number of columns
# EXTNAME = 'Joined  '           / table name
# TTYPE1  = 'ALPHA_J2000'        / label for column 1
# TFORM1  = 'D       '           / format for column 1
# TUNIT1  = 'deg     '           / units for column 1
# TTYPE2  = 'DELTA_J2000'        / label for column 2
# TFORM2  = 'D       '           / format for column 2
# TUNIT2  = 'deg     '           / units for column 2
# TTYPE3  = 'NUMBER  '           / label for column 3
# TFORM3  = 'K       '           / format for column 3
# TTYPE4  = 'X_IMAGE '           / label for column 4
# ...

# %%
N=['ALPHA_J2000','DELTA_J2000','NUMBER','r_MAG_AUTO','ZPDF']

# %%
Tabl2=TT2[N]

# %%
Tabl2.write('data_R_matched.dat',format='ascii.ipac')
